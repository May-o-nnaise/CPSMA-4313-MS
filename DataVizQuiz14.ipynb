# %% [markdown]
# <a href="https://colab.research.google.com/github/May-o-nnaise/CPSMA-4313-MS/blob/main/DataVizQuiz14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Quiz 14: PDF tables

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 61.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 73.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# installed the package

# %%
import pdfplumber

with pdfplumber.open("sample-tables.pdf") as pdfplumber:
  pdf = pdfplumber.open("sample-tables.pdf")

t = pdf.pages[1].extract_table(table_settings = {})

t
# Out:
# [['Rainfall\n(inches)', 'Americas', 'Asia', 'Europe', 'Africa'],
#  ['2010', None, None, None, None],
#  ['Average', '104', '201', '193', '144'],
#  ['24 hour high', '15', '26', '27', '18'],
#  ['12 hour high', '9', '10', '11', '12'],
#  ['2009', None, None, None, None],
#  ['Average', '133', '244', '155', '166'],
#  ['24 hour high', '27', '28', '29', '20'],
#  ['12 hour high', '11', '12', '13', '16']]

# %% [markdown]
# I chose to grab a random one so I just chose a random page and it looks like there is a rainfall one.

# %% [markdown]
# I went and pulled it up on the pdf and it is interesting to see how it interprets the merged cells by just including a bunch of "nones."

# %% [markdown]
# Here is the table incase you wanted to compare: ![image.png](data:image/png;base64,...)
