# %% [markdown]
# <a href="https://colab.research.google.com/github/May-o-nnaise/CPSMA-4313-MS/blob/main/DataVizQuiz19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Data_Sets/AB_NYC_2019.csv')

df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# Lets look at the availability 365

# %%
df.availability_365.hist()
# Out:
# <Axes: >

# %% [markdown]
# Lots of zeros, lets change that!

# %%
df.availability_365 = df.availability_365.replace(0, df.availability_365.mean())

# %% [markdown]
# Lets set the zeros to the average of the data

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.availability_365.hist()
# Out:
# <Axes: >

# %% [markdown]
# Maybe that wasnt a good idea... oh well.

# %%
df.last_review
# Out:
# 0        2018-10-19
# 1        2019-05-21
# 2               NaN
# 3        2019-07-05
# 4        2018-11-19
#             ...
# 48890           NaN
# 48891           NaN
# 48892           NaN
# 48893           NaN
# 48894           NaN
# Name: last_review, Length: 48895, dtype: object

# %% [markdown]
# Lets set the date of the last reviews to the very last known review day.

# %%
df.last_review = pa.to_datetime(df.last_review)
df.last_review = df.last_review.fillna(df.last_review.max())

# %% [markdown]
# I was getting some errors because some of the dates were actually strings so i set it to datetime

# %%
df.last_review
# Out:
# 0       2018-10-19
# 1       2019-05-21
# 2       2019-07-08
# 3       2019-07-05
# 4       2018-11-19
#            ...
# 48890   2019-07-08
# 48891   2019-07-08
# 48892   2019-07-08
# 48893   2019-07-08
# 48894   2019-07-08
# Name: last_review, Length: 48895, dtype: datetime64[ns]

# %% [markdown]
# Woohoo no more NaNs

# %% [markdown]
# Oh i forgot i was supposed to look at how many NaNs there were total

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# sure would suck to fix reviews per month!
