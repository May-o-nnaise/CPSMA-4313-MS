# %% [markdown]
# <a href="https://colab.research.google.com/github/May-o-nnaise/CPSMA-4313-MS/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %%bigquery --project dataviz-488505
# SELECT
#   COUNT(*) as total_rows
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    total_rows
# 0     2271152

# %%
# %%bigquery --project dataviz-488505
# SELECT
#   MAX(duration_minutes)
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      f0_
# 0  34238

# %%
# %%bigquery --project dataviz-488505
# SELECT
#   AVG(duration_minutes)
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          f0_
# 0  28.719178
